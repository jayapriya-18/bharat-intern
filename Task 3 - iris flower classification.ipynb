# %% [markdown]
# <h1>Import Packages</h1>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %% [markdown]
# <h1>Load the Dataset</h1>

# %%
iris = load_iris()
X = iris.data  # Features (sepal length, sepal width, petal length, petal width)
y = iris.target  # Target variable
df = pd.read_csv("C:\\Users\\wjaya\\iris_dataset.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0      5.352810     3.580031      1.497874     0.424089        0
# 1      5.373512     3.304544      1.495009     0.184864        0
# 2      4.979356     3.582120      1.414404     0.345427        0
# 3      5.152208     3.524335      1.444386     0.233367        0
# 4      5.298816     3.458968      1.431307     0.114590        0

# %% [markdown]
# <h1>Statistical Information About The Dataset</h1>

# %%
# Create a DataFrame for analysis
iris_df = pd.DataFrame(X, columns=iris.feature_names)
iris_df['species'] = y
# Display basic statistical information about the dataset
summary = iris_df.describe()
print("Basic Statistical Analysis of Iris Dataset:")
print(summary)
# Out:
# Basic Statistical Analysis of Iris Dataset:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# <h1>Visualize The Dataset</h1>

# %%
# Pairplot to visualize relationships between features
sns.pairplot(iris_df, hue="species", palette="Set1")
plt.show()

# %% [markdown]
# <h1> Visualize The Average</h1>

# %%
# Create a bar plot to visualize the average values
averages = averages.transpose()
averages.plot(kind='bar', figsize=(10, 6))
plt.title('Average Iris Dataset Features by Species')
plt.xlabel('Features')
plt.ylabel('Average Value')
plt.xticks(rotation=0)
plt.legend(title='Species', labels=['Setosa', 'Versicolor', 'Virginica'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Create a bar plot to visualize the average values
# ----> 2 averages = averages.transpose()
#       3 averages.plot(kind='bar', figsize=(10, 6))
#       4 plt.title('Average Iris Dataset Features by Species')
#
# NameError: name 'averages' is not defined

# %% [markdown]
# <h1>Scatterplots For Each Feature</h1>

# %%
iris_df = pd.DataFrame(features, columns=iris.feature_names)


plt.figure(figsize=(12, 8))

# Create scatterplots for each feature
for i, feature in enumerate(iris.feature_names):
    plt.subplot(2, 2, i+1)
    sns.scatterplot(data=iris_df, x=feature, y=feature, hue=iris_df.index, palette='viridis')
    plt.title(f'Scatterplot of {feature}')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Evaluate The Model's Accuracy </h1>

# %%
k = 3
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
